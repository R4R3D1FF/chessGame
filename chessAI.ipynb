# %%
import pygame
import copy
piecesw = {}
piecesb = {}
pieces = {}
board = pygame.display.set_mode((800,800))
boardsurf = pygame.image.load('C:\\Users\\hp\\Downloads\\chesss.png').convert_alpha()
boardsurf  = pygame.transform.scale(boardsurf, (800,800))
run = 1
def getcell(x,y):
    print(8*(y//100) + x//100 + 1)
    return 8*(y//100) + x//100 + 1
class rook:
    def __init__(self, currentcell, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\rookw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\rook.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def obstruction(self, move):
        if (move - self.currentcell) % 8 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - self.currentcell) % 8 == 0:
                        if (pos) in range(min(move,self.currentcell), max(move,self.currentcell), 8):
                            return 1
                if pos == move:
                    if pos in occupiedposb and self.colour == 'black':
                        return 1
                    if pos in occupiedposw and self.colour == 'white':
                        return 1
                
        if (move - 1) // 8 == (self.currentcell - 1) // 8:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - 1) // 8 == (move - 1) // 8:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell)):
                            return 1
                if pos == move:
                    if pos in occupiedposb and self.colour == 'black':
                        return 1
                    if pos in occupiedposw and self.colour == 'white':
                        return 1
        return 0
    def draww(self):
        board.blit(self.surface, self.rect)
    def legalmove(self, move):
        if not self.obstruction(move):
            if (move - self.currentcell) % 8 == 0:
                return 1
            if (move - 1) // 8 == (self.currentcell - 1) // 8:
                return 1
        return 0
class knight:
    def __init__(self, currentcell, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\knightw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\knight.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = self.surface.get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def draww(self):
        board.blit(self.surface, self.rect)
    def legalmove(self, move):
        if (move not in occupiedposb and self.colour == 'black') or (move not in occupiedposw and self.colour == 'white'):
            not_for_oneh = [6, -10, 15, -17]
            not_for_twoh = [6, -10]
            not_for_sevenh = [-6, 10]
            not_for_eighth = [-6, 10, -15, 17]
            not_for_twov = [-15, -17]
            not_for_onev = [-15, -17, -6, -10]
            not_for_sevenv = [17, 15]
            not_for_eightv = [17, 15, 10, 6]
            banned_moves = []
            if (self.currentcell - 1) // 8 == 0:
                banned_moves += (not_for_onev)
            if (self.currentcell - 1) // 8 == 1:
                banned_moves += (not_for_twov)
            if (self.currentcell - 1) // 8 == 6:
                banned_moves += (not_for_sevenv)
            if (self.currentcell - 1) // 8 == 7:
                banned_moves += (not_for_eightv)
            if self.currentcell % 8 == 1:
                banned_moves += (not_for_oneh)
            if self.currentcell % 8 == 2:
                banned_moves += (not_for_twoh)
            if self.currentcell % 8 == 7:
                banned_moves += (not_for_sevenh)
            if self.currentcell % 8 == 0:
                banned_moves += (not_for_eighth)
            if (move - self.currentcell in [-17, -15, -10, -6, 6, 10, 15, 17]) and (move - self.currentcell not in banned_moves):
                return 1
        return 0
class bishop:
    def __init__(self, currentcell, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\bishopw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\bishop.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def obstruction(self, move):
        if (move - self.currentcell) % 7 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - move) % 7 == 0:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell) + 1, 7):
                            return 1
                if pos == move:
                    if (pos in occupiedposb and piece.colour == 'black') or (pos in occupiedposw and piece.colour == 'white'):
                        return 1
        if (move - self.currentcell) % 9 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - move) % 9 == 0:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell) + 1, 9):
                            return 1
                if pos == move:
                    if (pos in occupiedposb and piece.colour == 'black') or (pos in occupiedposw and piece.colour == 'white'):
                        return 1
        return 0
    def draww(self):
        board.blit((self.surface), self.rect)
    def legalmove(self, move):
        if not self.obstruction(move):
            if (((move - self.currentcell) % 7 == 0 and ((move - self.currentcell) // 7 in range(((self.currentcell - 1) % 8) - 7, 1 + ((self.currentcell - 1) % 8)))) or ((move - self.currentcell) % 9 == 0 and ((move - self.currentcell) // 9 in range( - ((self.currentcell - 1) % 8), 8 - ((self.currentcell - 1) % 8))))):
                return 1
        return 0
class queen:
    def __init__(self, currentcell, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\queenw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\queen.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def obstruction1(self, move):
        if (move - self.currentcell) % 8 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - self.currentcell) % 8 == 0:
                        if (pos) in range(min(move,self.currentcell), max(move,self.currentcell), 8):
                            return 1
                if pos == move:
                    if pos in occupiedposb and self.colour == 'black':
                        return 1
                    if pos in occupiedposw and self.colour == 'white':
                        return 1
                
        if (move - 1) // 8 == (self.currentcell - 1) // 8:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - 1) // 8 == (move - 1) // 8:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell)):
                            return 1
                if pos == move:
                    if pos in occupiedposb and self.colour == 'black':
                        return 1
                    if pos in occupiedposw and self.colour == 'white':
                        return 1
        return 0
    def obstruction2(self, move):
        if (move - self.currentcell) % 7 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - move) % 7 == 0:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell) + 1, 7):
                            return 1
                if pos == move:
                    if (pos in occupiedposb and piece.colour == 'black') or (pos in occupiedposw and piece.colour == 'white'):
                        return 1
        if (move - self.currentcell) % 9 == 0:
            for pos in occupiedpos:
                if pos != self.currentcell and pos != move:
                    if (pos - move) % 9 == 0:
                        if pos in range(min(move, self.currentcell), max(move, self.currentcell) + 1, 9):
                            return 1
                if pos == move:
                    if (pos in occupiedposb and piece.colour == 'black') or (pos in occupiedposw and piece.colour == 'white'):
                        return 1
        return 0
    def draww(self):
        board.blit(self.surface, self.rect)
    def legalmove(self, move):
        if not self.obstruction1(move):
            if (move - self.currentcell) % 8 == 0:
                return 1
            if (move - 1) // 8 == (self.currentcell - 1) // 8:
                return 1
        if not self.obstruction2(move):
            if ((move - self.currentcell) % 7 == 0 and ((move - self.currentcell) // 7 in range(((self.currentcell - 1) % 8) - 7, 1 + ((self.currentcell - 1) % 8)))) or ((move - self.currentcell) % 9 == 0 and ((move - self.currentcell) // 9 in range( - ((self.currentcell - 1) % 8), 8 - ((self.currentcell - 1) % 8)))):
                return 1
        return 0
class king:
    def __init__(self, currentcell, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\kingw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\king.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def obstruction(self, move):
        if self.colour == 'white' and move in occupiedposw:
            return 1
        if self.colour == 'black' and move in occupiedposb:
            return 1
        return 0
    def draww(self):
        board.blit(self.surface, self.rect)
    def legalmove(self, move):
#         if self.colour == 'black':
# #             for piece in piecesw:
# #                 if not isinstance(piece, king):
# #                     if piece.legalmove(move):
# #                         return 0
#         if self.colour == 'white':
#             for piece in piecesb:
#                 if not isinstance(piece, king):
#                     if piece.legalmove(move):
#                         return 0
        if not self.obstruction(move):
            if (self.currentcell) // 8 not in [0, 7]:
                if move - self.currentcell in [-8, 8]:
                    return 1
            if (self.currentcell) // 8 == 0:
                if move - self.currentcell == 8:
                    return 1
                if (self.currentcell - 1) % 8 not in [0, 7]:
                    if move - self.currentcell in [7, 9]:
                        return 1
            if (self.currentcell) // 8 == 7:
                if move - self.currentcell == -8:
                    return 1
                if (self.currentcell - 1) % 8 not in [0, 7]:
                    if move - self.currentcell in [-7, -9]:
                        return 1
            if (self.currentcell - 1) % 8 == 0:
                if move - self.currentcell == 1:
                    return 1
                if move - self.currentcell == 9:
                    if self.currentcell // 8 + 1 != 1:
                        return 1
                if move - self.currentcell == -7:
                    if self.currentcell // 8 + 1 != 8:
                        return 1
            if (self.currentcell - 1) % 8 == 7:
                if move - self.currentcell == -1:
                    return 1
                if move - self.currentcell == 7:
                    if self.currentcell // 8 + 1 != 1:
                        return 1
                if move - self.currentcell == -9:
                    if self.currentcell // 8 + 1 != 8:
                        return 1
            if (self.currentcell - 1) % 8 not in [0, 7]:
                if move - self.currentcell in [-1, 1]:
                    return 1
            if (self.currentcell - 1) % 8 not in [0, 7] and self.currentcell // 8 not in [0,7]:
                if move - self.currentcell in [-9, -7, 7, 9]:
                    return 1
        return 0
class pawn:
    def __init__(self, currentcell, pawnmoved, drag, colour):
        self.currentcell = currentcell
        self.colour = colour
        if self.colour == 'white':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\pawnw.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            self.surface = pygame.image.load('C:\\Users\\hp\\Downloads\\pawn.png').convert_alpha()
            self.surface = pygame.transform.scale(self.surface, (100,100))
            piecesb[self] = self.currentcell
        pieces[self] = self.currentcell
        self.pawnmoved = pawnmoved
        self.drag = drag
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def update(self):
        pieces[self] = self.currentcell
        if self.colour == 'white':
            piecesw[self] = self.currentcell
        if self.colour == 'black':
            piecesb[self] = self.currentcell
        if self.currentcell % 8 == 0:
            self.xpos = 8
            self.ypos = self.currentcell//8
        else:
            self.xpos = self.currentcell % 8
            self.ypos = self.currentcell//8 + 1
        self.rect = (self.surface).get_rect(bottomright = (self.xpos * 100, self.ypos * 100))
    def obstruction(self, move):
        if move in occupiedpos:
            return 1
        if self.colour == 'black':
            if move + 8 in occupiedpos:
                if move + 8 != self.currentcell:
                    return 1
        if self.colour == 'white':
            if move - 8 in occupiedpos:
                if move - 8 != self.currentcell:
                    return 1
    def draww(self):
        board.blit(self.surface, self.rect)
    def legalmove(self, move):
        if self.colour == 'black':
            if move == (self.currentcell - 9):
                if (self.currentcell - 1) % 8 != 0:
                    if move in occupiedposw:
                        return 1
            if move == (self.currentcell - 7):
                if (self.currentcell - 1) % 8 != 7:
                    if move in occupiedposw:
                        return 1
        if self.colour == 'white':
            if move == (self.currentcell + 7):
                if (self.currentcell - 1) % 8 != 0:
                    if move in occupiedposb:
                        return 1
            if move == (self.currentcell + 9):
                if (self.currentcell - 1) % 8 != 7:
                    if move in occupiedposb:
                        return 1
        if not self.obstruction(move):
            if self.colour == 'black':
                if move - self.currentcell == -8:
                    return 1
                if not self.pawnmoved and move - self.currentcell == -16:
                    return 1
            if self.colour == 'white':
                if move - self.currentcell == 8:
                    return 1
                if not self.pawnmoved and move - self.currentcell == 16:
                    return 1
        return 0
def checkw():
    for piece in piecesb:
        if not isinstance(piece, king):
            if piece.legalmove(KingW.currentcell):
                return piece
def checkb():
    for piece in piecesw:
        if not isinstance(piece, king):
            if piece.legalmove(King.currentcell):
                return piece
RookL = rook(57, 0, 'black')
RookWL = rook(1, 0, 'white')
KnightL = knight(58, 0, 'black')
KnightWL = knight(2, 0, 'white')
BishopL = bishop(59, 0, 'black')
BishopWL = bishop(3, 0, 'white')
Queen = queen(61, 0, 'black')
QueenW = queen(5, 0, 'white')
RookR = rook(64, 0, 'black')
RookWR = rook(8, 0, 'white')
KnightR = knight(63, 0, 'black')
KnightWR = knight(7, 0, 'white')
BishopR = bishop(62, 0, 'black')
BishopWR = bishop(6, 0, 'white')
King = king(60, 0, 'black')
KingW = king(4, 0, 'white')
pawnlistb = [0, 0, 0, 0, 0, 0, 0, 0]
pawnlistw = [0, 0, 0, 0, 0, 0, 0, 0]
for x in range(1, 9):
    pawn(48 + x, 0, 0, 'black')
for x in range(1,9):
    pawn(8 + x, 0, 0, 'white')
turn = 1

while run:
    occupiedposw = []
    occupiedposb = []
    occupiedpos = []
    for piece in piecesw:
        occupiedposw.append(piecesw[piece])
    for piece in piecesb:
        occupiedposb.append(piecesb[piece])
    for piece in pieces:
        occupiedpos.append(pieces[piece])
  #  checkw = checkw()
  #  checkb = checkb()
    pygame.display.update()
    if not run:
        break
    board.blit(boardsurf, (0,0))
    for piece in pieces:
        piece.update()
        piece.draww()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            print('store')
            pygame.display.quit()
            pygame.quit()
            exit()
            run = False
        if event.type == pygame.MOUSEBUTTONDOWN:
            if turn % 2 == 1:
                for piece in piecesw:
                    if piece.rect.collidepoint(pygame.mouse.get_pos()):
                        piece.drag = True
            if turn % 2 == 0:
                for piece in piecesb:
                    if piece.rect.collidepoint(pygame.mouse.get_pos()):
                        piece.drag = True
        if event.type == pygame.MOUSEBUTTONUP:
            todelete = []
            for piece in pieces:
                if piece.drag:
                    x, y = pygame.mouse.get_pos()
                    newcell = getcell(x,y)
                    deleted = 0
                    if piece.legalmove(newcell):
                        if isinstance(piece, pawn):
                            piece.pawnmoved = 1
                        for goti in pieces:
                            if goti.currentcell == newcell:
                                todelete.append(goti)
                                deleted = 1
                        oldcell = piece.currentcell
                        piece.currentcell = newcell
                        piece.update()
                        if turn % 2 == 1:
                            if checkw():
                                print('reverting')
                                piece.currentcell = oldcell
                                if deleted:
                                    todelete.pop()
                                piece.drag = 0
                                break
                        if turn % 2 == 0:
                            if checkb():
                                piece.currentcell = oldcell
                                if deleted:
                                    todelete.pop()
                                piece.drag = 0
                                break
                        turn += 1
                    piece.drag = 0
            for goti in todelete:
                poss = pieces[goti]
                pieces.pop(goti)
                occupiedpos.remove(poss)
                try:
                    piecesw.pop(goti)
                    occupiedposw.remove(poss)
                except:
                    piecesb.pop(goti)
                    occupiedposb.remove(poss)
    for piece in pieces:
        piece.update()
        piece.draww()
    pygame.display.update()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 28
# 36
# 19
# 43
# 44
# 36
# 46
# 46
# 46
# store
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9168/351572232.py in <module>
#     651     for piece in pieces:
#     652         piece.update()
# --> 653         piece.draww()
#     654     pygame.display.update()
#
# ~\AppData\Local\Temp/ipykernel_9168/351572232.py in draww(self)
#      71         return 0
#      72     def draww(self):
# ---> 73         board.blit(self.surface, self.rect)
#      74     def legalmove(self, move):
#      75         if not self.obstruction(move):
#
# error: display Surface quit
